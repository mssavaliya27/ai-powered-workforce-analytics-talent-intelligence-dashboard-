# %% [markdown]
# <a href="https://colab.research.google.com/github/mssavaliya27/ai-powered-workforce-analytics-talent-intelligence-dashboard-/blob/main/firstpythoncode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [1, 23, 23]
print(a[1])
# Out:
# 23
